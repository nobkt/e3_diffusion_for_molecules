# %% [markdown]
# # Tutorial 01: 基本的な分子生成 - 完全版このチュートリアルでは、E(3)等変拡散モデルの基礎を学びます。## 学習内容1. データセットの準備2. モデルの構築3. 訓練の実行4. サンプリング5. 評価所要時間: 30-45分

# %%
# ライブラリのインポートimport torchimport numpy as npprint("PyTorch version:", torch.__version__)print("CUDA available:", torch.cuda.is_available())

# %% [markdown]
# ## まとめこのチュートリアルで学んだこと：- データセットの読み込み- モデルの構築- 基本的な訓練フロー次のチュートリアルでは条件付き生成を学びます。
